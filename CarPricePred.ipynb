# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

sns.set()

from datetime import date

import warnings
warnings.filterwarnings('ignore')

# %%
carData = pd.read_csv('car data.csv')

# %%
carData.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
carData.shape
# Out:
# (8128, 13)

# %%
carData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
(carData.isna().sum()/carData.shape[0])*100
# Out:
# name             0.000000
# year             0.000000
# selling_price    0.000000
# km_driven        0.000000
# fuel             0.000000
# seller_type      0.000000
# transmission     0.000000
# owner            0.000000
# mileage          2.718996
# engine           2.718996
# max_power        2.645177
# torque           2.731299
# seats            2.718996
# dtype: float64

# %% [markdown]
# # EDA

# %%
fib,axes = plt.subplots(1,1, figsize=(8,4))
g = sns.countplot(carData.year,ax=axes)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '1983'),
#  Text(1, 0, '1991'),
#  Text(2, 0, '1994'),
#  Text(3, 0, '1995'),
#  Text(4, 0, '1996'),
#  Text(5, 0, '1997'),
#  Text(6, 0, '1998'),
#  Text(7, 0, '1999'),
#  Text(8, 0, '2000'),
#  Text(9, 0, '2001'),
#  Text(10, 0, '2002'),
#  Text(11, 0, '2003'),
#  Text(12, 0, '2004'),
#  Text(13, 0, '2005'),
#  Text(14, 0, '2006'),
#  Text(15, 0, '2007'),
#  Text(16, 0, '2008'),
#  Text(17, 0, '2009'),
#  Text(18, 0, '2010'),
#  Text(19, 0, '2011'),
#  Text(20, 0, '2012'),
#  Text(21, 0, '2013'),
#  Text(22, 0, '2014'),
#  Text(23, 0, '2015'),
#  Text(24, 0, '2016'),
#  Text(25, 0, '2017'),
#  Text(26, 0, '2018'),
#  Text(27, 0, '2019'),
#  Text(28, 0, '2020')]

# %%
carData.year.value_counts()
# Out:
# 2017    1018
# 2016     859
# 2018     807
# 2015     776
# 2013     670
# 2012     651
# 2014     621
# 2011     592
# 2019     583
# 2010     394
# 2009     246
# 2008     214
# 2007     183
# 2006     124
# 2005      97
# 2020      74
# 2004      62
# 2003      49
# 2002      27
# 2000      22
# 1999      18
# 1997      11
# 1998      10
# 2001      10
# 1994       3
# 1996       3
# 1995       2
# 1991       1
# 1983       1
# Name: year, dtype: int64

# %% [markdown]
# * As we can see most of the data
# * Most oof the cars got sold from 2011 to 2019

# %%
# Let's checl selling price distribution according to year.
_,axes = plt.subplots(2,2,figsize=(10,10))
sns.distplot(carData.selling_price,ax = axes[0][0])
axes[0][0].set_title('Distribution')
sns.boxplot(carData.selling_price,ax = axes[0][1])
axes[0][1].set_title('Outliers')
sns.jointplot(y='selling_price',x='year',ax = axes[1][0],data=carData)
axes[1][0].set_title('Year wise selling')
print(carData.selling_price.describe())
# Out:
# count    8.128000e+03
# mean     6.382718e+05
# std      8.062534e+05
# min      2.999900e+04
# 25%      2.549990e+05
# 50%      4.500000e+05
# 75%      6.750000e+05
# max      1.000000e+07
# Name: selling_price, dtype: float64

# %% [markdown]
# Looking at car selling price as per year.
# * Considering year as the purchase of car.
# * For recenlty or cars bought in recent pas years are having high seeling price.
# * We can see there are some outliers.

# %%
_,axes = plt.subplots(2,2,figsize=(10,10))
sns.displot(carData.km_driven,ax=axes[0][0])
axes[0][0].set_title('Distribution')
sns.jointplot(y='selling_price',x='km_driven',ax = axes[0][1],data=carData)
axes[0][1].set_title('km_driven vs selling price')
sns.boxplot(carData.km_driven,ax = axes[1][0])
axes[1][0].set_title('Outliers')


print(carData.km_driven.describe())
# Out:
# count    8.128000e+03
# mean     6.981951e+04
# std      5.655055e+04
# min      1.000000e+00
# 25%      3.500000e+04
# 50%      6.000000e+04
# 75%      9.800000e+04
# max      2.360457e+06
# Name: km_driven, dtype: float64

# %% [markdown]
# Looking at car selling price as per number of kms  of car.
# * Considering number of kms of car, lesser number of kms driven car has more price.
# * And it also depends on car brnad.
# * We can see there are some outliers.

# %%
_,axes = plt.subplots(1,3,figsize=(10,10))
sns.countplot(carData.fuel,ax=axes[0])
axes[0].set_title('Distribution')
sns.catplot(y='selling_price',data=carData,ax=axes[1],x='fuel')
axes[1].set_title('fuel vs selling price')
sns.catplot(y='selling_price',data=carData,ax=axes[2],x='fuel', hue='transmission')
axes[2].set_title('fuel vs selling price and hue is transmission of the car')

print(carData.fuel.describe())
# Out:
# count       8128
# unique         4
# top       Diesel
# freq        4402
# Name: fuel, dtype: object

# %% [markdown]
# Looking at car selling price as per fuel type of car.
# * Most of the cars have desiel, petrol respectively.
# * And lookign at catplot desile and petrol fuel type cars have more price comapre to LPG and CNG.
# * LPG and CNG cars are of of type Manual transmission have lesser selling price.
# * Diesel and pretrol have both Manual and Automatic transmission.
# * Manual transmission has lesser selling price in both Diesel and Petrol cars.
# * Where as Automatic transmission has higher selling price in both Diesel and Petrol cars.

# %%
_,axes = plt.subplots(1,2,figsize=(10,10))
sns.countplot(carData.seller_type,ax=axes[0])
axes[0].set_title('Distribution')
sns.catplot(y='selling_price',data=carData,ax=axes[1],x='seller_type')
axes[1].set_title('seller_type vs selling price')
# Out:
# Text(0.5, 1.0, 'seller_type vs selling price')

# %% [markdown]
# Looking at car selling price as per seller_type type of car.
# * Most of the cars have sold by individuals.
# * Dealer sell cars at higher price.
# * Trust mark dealers sell cars at lower price.

# %%
_,axes = plt.subplots(1,3,figsize=(15,10))
sns.countplot(carData.owner,ax=axes[0])
axes[0].set_title('Distribution')
sns.catplot(y='selling_price',data=carData,ax=axes[1],x='owner')
axes[1].set_title('owner vs selling price')
sns.catplot(y='selling_price',data=carData,ax=axes[2],x='owner',hue='seller_type')
axes[2].set_title('owner vs selling price according to seller_type')

print(carData.owner.unique())
# Out:
# ['First Owner' 'Second Owner' 'Third Owner' 'Fourth & Above Owner'
#  'Test Drive Car']

# %% [markdown]
# Looking at owner, sellertype andselling price.
# * Most of the cars sold by 'First owners'
# * Looking at seller type, I can say individuals sell cars at lower price and Dealer sell cars at higher price.

# %%
carData.mileage.value_counts()
# Here we have 393 unique  mileage  of selling cars.
# Out:
# 18.9 kmpl     225
# 19.7 kmpl     173
# 18.6 kmpl     164
# 21.1 kmpl     157
# 17.0 kmpl     133
#              ...
# 14.5 kmpl       1
# 18.44 kmpl      1
# 15.63 kmpl      1
# 18.24 kmpl      1
# 14.9 kmpl       1
# Name: mileage, Length: 393, dtype: int64

# %%
carData.max_power.value_counts()
# Here we have 322 unique  power  of selling cars.
# Out:
# 74 bhp       377
# 81.80 bhp    220
# 88.5 bhp     204
# 67 bhp       165
# 46.3 bhp     162
#             ...
# 58.3 bhp       1
# 194 bhp        1
# 161 bhp        1
# 141.1 bhp      1
# 86 bhp         1
# Name: max_power, Length: 322, dtype: int64

# %%
carData.torque.value_counts()
# Here we have 441 unique  torque with rpm of  selling cars.
# Out:
# 190Nm@ 2000rpm         530
# 200Nm@ 1750rpm         445
# 90Nm@ 3500rpm          405
# 113Nm@ 4200rpm         223
# 114Nm@ 4000rpm         171
#                       ...
# 4.8kgm@ 3000rpm          1
# 136.3Nm@ 4200rpm         1
# 355Nm@ 4500rpm           1
# 185Nm@ 1750-2750rpm      1
# 250Nm@ 1500-4500rpm      1
# Name: torque, Length: 441, dtype: int64

# %%
sns.countplot(carData.seats)
print(carData.seats.value_counts())
# Out:
# 5.0     6254
# 7.0     1120
# 8.0      236
# 4.0      133
# 9.0       80
# 6.0       62
# 10.0      19
# 2.0        2
# 14.0       1
# Name: seats, dtype: int64

# %% [markdown]
# # Preprocessing

# %%
carData['num_of_year'] = carData['year'].apply(lambda x: date.today().year-x)

# %%
carData.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  num_of_year
# ...
